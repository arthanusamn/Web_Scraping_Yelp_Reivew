# %% [markdown]
# This is the web scraping on Yelp Twin Cities

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests soupsieve lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# go get the web content

# -*- coding: utf-8 -*-
from bs4 import BeautifulSoup
import requests

url = 'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Minneapolis%2C%20MN'
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'}

response = requests.get(url, headers=headers)
print(response.content)
# Out:
# b'<!DOCTYPE html><html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(/\x08no-js\x08/,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><meta http-equiv="Content-Language" content="en-US" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel="mask-icon" sizes="any" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/97ea654d5227/assets/img/logos/yelp_burst.svg" content="#c41200"><link rel="shortcut icon" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/118ff475a341/assets/img/logos/favicon.ico"><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script async src="https://www.google-analytics.com/
# ...

# %%
soup=BeautifulSoup(response.content,'lxml')

for item in soup.select('[class*=container]'):
    try:
        #print(item)
        if item.find('h4'):
            name=item.find('h4').get_text()
            print(name)
            print(soup.select('[class*=reviewCount]')[0].get_text())
            print(soup.select('[aria-label*=rating]')[0]['aria-label'])
            print(soup.select('[class*=secondaryAttributes]')[0].get_text())
            print(soup.select('[class*=priceRange]')[0].get_text())
            print(soup.select('[class*=priceCategory]')[0].get_text())
            
            print('---------------')
            
    except Exception as e:
        raise e
        print('')
# Out:
# Scott Ja-Mamas
# 73
# 4 star rating
# (612) 823-44503 W Diamond Lake RdSouthwest
# $$$
# Barbeque
# ---------------
# Ray J’s American Grill
# 73
# 4 star rating
# (612) 823-44503 W Diamond Lake RdSouthwest
# $$$
# Barbeque
# ---------------
# 1. Spoon and Stable
# 73
# 4 star rating
# (612) 823-44503 W Diamond Lake RdSouthwest
# $$$
# Barbeque
# ---------------
# 2. Hell’s Kitchen
# 73
# 4 star rating
# (612) 823-44503 W Diamond Lake RdSouthwest
# $$$
# Barbeque
# ---------------
# 3. Bar La Grassa
# 73
# 4 star rating
# (612) 823-44503 W Diamond Lake RdSouthwest
# $$$
# Barbeque
# ---------------
# 4. 112 Eatery
# 73
# 4 star rating
# (612) 823-44503 W Diamond Lake RdSouthwest
# $$$
# Barbeque
# ---------------
# 5. Stepchld
# 73
# 4 star rating
# (612) 823-44503 W Diamond Lake RdSouthwest
# $$$
# Barbeque
# ---------------
# 6. The Lowry
# 73
# 4 star rating
# (612) 823-44503 W Diamond Lake RdSouthwest
# $$$
# Barbeque
# ---------------
# 7. Hen House Eatery
# 73
# 4 star rating
# ...
